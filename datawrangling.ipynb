# %% [markdown]
# <a href="https://colab.research.google.com/github/anandsingh728/Project2/blob/main/datawrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #install numpy <For Google Colab>
 import numpy as np
 import pandas as pd
 import seaborn as sns
 import matplotlib.pyplot as plt

# %%
Dataset_1 = pd.read_excel(r"/content/dataset_1.xlsx")

# %%
#checking shape of the data
Dataset_1.shape
# Out:
# (610, 10)

# %%
#printing last 05 rows of the data
Dataset_1.tail(5)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
#to check the missing values
Dataset_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
#to check the unique values from the data
Dataset_1["mnth"].unique()
# Out:
# array([1])

# %%
Dataset_1["season"].unique()
# Out:
# array([1])

# %%
#To get the information on dataset
Dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
#Description of data
Dataset_1.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
#Dataset_2 Process

# %%
dataset_2 = pd.read_excel(r"/content/dataset_2.xlsx")

# %%
dataset_2.shape
# Out:
# (610, 8)

# %%
# to print the first 10 rows of dataset 2
dataset_2.head(10)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81     0.0000       3          13   16
# 1           1        2  0.2727  0.80     0.0000       8          32   40
# 2           2        3  0.2727  0.80     0.0000       5          27   32
# 3           3        4  0.2879  0.75     0.0000       3          10   13
# 4           4        5  0.2879  0.75     0.0000       0           1    1
# 5           5        6  0.2576  0.75     0.0896       0           1    1
# 6           6        7  0.2727  0.80     0.0000       2           0    2
# 7           7        8  0.2576  0.86     0.0000       1           2    3
# 8           8        9     NaN  0.75     0.0000       1           7    8
# 9           9       10  0.3485  0.76     0.0000       8           6   14

# %%
# to remove unnecessary columns using drop function.
dataset_2.drop(['Unnamed: 0'],axis =1,inplace = True)

# %%
print(dataset_2.head(10))
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81     0.0000       3          13   16
# 1        2  0.2727  0.80     0.0000       8          32   40
# 2        3  0.2727  0.80     0.0000       5          27   32
# 3        4  0.2879  0.75     0.0000       3          10   13
# 4        5  0.2879  0.75     0.0000       0           1    1
# 5        6  0.2576  0.75     0.0896       0           1    1
# 6        7  0.2727  0.80     0.0000       2           0    2
# 7        8  0.2576  0.86     0.0000       1           2    3
# 8        9     NaN  0.75     0.0000       1           7    8
# 9       10  0.3485  0.76     0.0000       8           6   14

# %%
#Dataset_2 Information with object type
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   atemp       599 non-null    float64
#  2   hum         610 non-null    float64
#  3   windspeed   610 non-null    float64
#  4   casual      610 non-null    int64
#  5   registered  610 non-null    int64
#  6   cnt         610 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 33.5 KB

# %%
#to check the count of missing values
dataset_2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
#To fill the missing values using functions
dataset_2['atemp'].fillna(dataset_2['atemp'].mean(),inplace = True)
print(dataset_2.isnull().sum())
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset_2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078120    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.227300    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
# Dataset_3 Process

# %%
Dataset_3 =pd.read_excel(r"/content/dataset_3.xlsx")
Dataset_3.shape
# Out:
# (390, 16)

# %%
# To print last 6 rows of the data
Dataset_3.tail(6)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 384      614 2011-01-28       1   0     1  19    False        5           2
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 384  0.24  0.2424  0.75     0.1343       5          84   89
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
#checking the unique value in the columns
Dataset_3['holiday'].unique()
# Out:
# array([False])

# %%
#checking the missing values in the dataset set
Dataset_3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
Dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
Dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
Dataset_3.describe()
# Out:
#            instant                         dteday  season     yr        mnth  \
# count   390.000000                            390   390.0  390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0    0.0    1.800000
# min     611.000000            2011-01-28 00:00:00     1.0    0.0    1.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    0.0    2.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0    0.0    2.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0    0.0    2.000000
# max    1000.000000            2011-02-14 00:00:00     1.0    0.0    2.000000
# std     112.727548                            NaN     0.0    0.0    0.400514
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    11.687179    2.989744    1.484615    0.220000    0.230424    0.613769
# ...

# %%
Dataset_3.shape
# Out:
# (390, 16)

# %%
#To merge the data using inner join method

# %%
Data = pd.merge(Dataset_1,dataset_2,on = 'instant', how ='inner')

# %%
print(Data)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
#To print the first 3 rows of the merged data
Data.head(3)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  atemp       610 non-null    float64
#  11  hum         610 non-null    float64
#  12  windspeed   610 non-null    float64
#  13  casual      610 non-null    int64
#  14  registered  610 non-null    int64
#  15  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 72.2 KB

# %%
Data.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885    0.199935    0.562475
# min      0.000000    0.000000    1.000000    0.020000    0.000000    0.210000
# ...

# %%
#To concatenate the merged data with Dataset_3

# %%
concatenated_data = pd.concat([Data,Dataset_3],ignore_index = True)

# %%
concatenated_data.head(5)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
concatenated_data.shape
# Out:
# (1000, 16)

# %%
concatenated_data['mnth'].unique()
# Out:
# array([1, 2])

# %%
concatenated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   int64
#  3   yr          1000 non-null   int64
#  4   mnth        1000 non-null   int64
#  5   hr          1000 non-null   int64
#  6   holiday     1000 non-null   bool
#  7   weekday     1000 non-null   int64
#  8   weathersit  1000 non-null   int64
#  9   temp        1000 non-null   float64
#  10  atemp       1000 non-null   float64
#  11  hum         1000 non-null   float64
#  12  windspeed   1000 non-null   float64
#  13  casual      1000 non-null   int64
#  14  registered  1000 non-null   int64
#  15  cnt         1000 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 118.3 KB

# %%
#To replace missing values in the concatenated data

concatenated_data['yr'].fillna(concatenated_data['yr'].mean(),inplace =True)
print(concatenated_data.isnull().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
concatenated_data['holiday'].fillna(concatenated_data['holiday'].mean(),inplace =True)
print(concatenated_data.isnull().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
concatenated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   int64
#  3   yr          1000 non-null   int64
#  4   mnth        1000 non-null   int64
#  5   hr          1000 non-null   int64
#  6   holiday     1000 non-null   bool
#  7   weekday     1000 non-null   int64
#  8   weathersit  1000 non-null   int64
#  9   temp        1000 non-null   float64
#  10  atemp       1000 non-null   float64
#  11  hum         1000 non-null   float64
#  12  windspeed   1000 non-null   float64
#  13  casual      1000 non-null   int64
#  14  registered  1000 non-null   int64
#  15  cnt         1000 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 118.3 KB

# %%
concatenated_data.describe()
# Out:
#            instant                      dteday  season      yr         mnth  \
# count  1000.000000                        1000  1000.0  1000.0  1000.000000
# mean    500.500000  2011-01-22 15:56:09.600000     1.0     0.0     1.312000
# min       1.000000         2011-01-01 00:00:00     1.0     0.0     1.000000
# 25%     250.750000         2011-01-11 00:00:00     1.0     0.0     1.000000
# 50%     500.500000         2011-01-22 00:00:00     1.0     0.0     1.000000
# 75%     750.250000         2011-02-03 00:00:00     1.0     0.0     2.000000
# max    1000.000000         2011-02-14 00:00:00     1.0     0.0     2.000000
# std     288.819436                         NaN     0.0     0.0     0.463542
#
#                 hr      weekday   weathersit         temp        atemp  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     11.753000     2.982000     1.480000     0.205900     0.211826
# ...

# %%
#to check the outliers and remove

# %%
sns.boxplot(concatenated_data['casual'])
# Out:
# <Axes: ylabel='casual'>

# %%
#Statistical Methods using IQR method

# %%
df = pd.DataFrame(concatenated_data)

# %%
print("Outliers using IQR method:")
print(outliers_iqr)
# Out:
# Outliers using IQR method:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 10        11 2011-01-01       1   0     1  10        0        6           1
# 11        12 2011-01-01       1   0     1  11        0        6           1
# 12        13 2011-01-01       1   0     1  12        0        6           1
# 13        14 2011-01-01       1   0     1  13        0        6           2
# 14        15 2011-01-01       1   0     1  14        0        6           2
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 980      990 2011-02-13       1   0     2  21        0        0           1
# 981      991 2011-02-13       1   0     2  22        0        0           1
# 982      992 2011-02-13       1   0     2  23        0        0           1
# 983      993 2011-02-14       1   0     2   0        0        1           1
# 984      994 2011-02-14       1   0     2   1        0        1           1
#
# ...

# %%
concatenated_data_no_outlier = concatenated_data[(concatenated_data.casual>0)&(concatenated_data.casual<4)]
sns.boxplot(concatenated_data_no_outlier['casual'])
# Out:
# <Axes: ylabel='casual'>

# %%
# To Check the correlation of the data
concatenated_data.corr()
# Out:
#              instant    dteday  season  yr      mnth        hr   holiday  \
# instant     1.000000  0.999540     NaN NaN  0.802477  0.000060 -0.063013
# dteday      0.999540  1.000000     NaN NaN  0.804299 -0.022421 -0.068456
# season           NaN       NaN     NaN NaN       NaN       NaN       NaN
# yr               NaN       NaN     NaN NaN       NaN       NaN       NaN
# mnth        0.802477  0.804299     NaN NaN  1.000000 -0.025646 -0.105600
# hr          0.000060 -0.022421     NaN NaN -0.025646  1.000000 -0.005753
# holiday    -0.063013 -0.068456     NaN NaN -0.105600 -0.005753  1.000000
# weekday     0.008157  0.010248     NaN NaN  0.034710  0.007531 -0.148682
# weathersit  0.030439  0.033310     NaN NaN  0.014061 -0.055802  0.165443
# temp        0.023406  0.022342     NaN NaN  0.159660  0.203512 -0.059728
# atemp       0.077546  0.078681     NaN NaN  0.192216  0.148524 -0.072091
# hum         0.062116  0.073485     NaN NaN  0.066587 -0.194853 -0.037542
# ...

# %%
df_cleaned = df.dropna()

# %%
print("\nDataFrame after removing rows with missing values:")
print(df_cleaned)
# Out:
# DataFrame after removing rows with missing values:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 995      615 2011-01-28       1   0     1  20    False        5           2
# 996      616 2011-01-28       1   0     1  21    False        5           2
# 997      617 2011-01-28       1   0     1  22    False        5           1
# 998      618 2011-01-28       1   0     1  23    False        5           1
# 999      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
concatenated_data.corr()
# Out:
#              instant    dteday  season  yr      mnth        hr   holiday  \
# instant     1.000000  0.999540     NaN NaN  0.802477  0.000060 -0.063013
# dteday      0.999540  1.000000     NaN NaN  0.804299 -0.022421 -0.068456
# season           NaN       NaN     NaN NaN       NaN       NaN       NaN
# yr               NaN       NaN     NaN NaN       NaN       NaN       NaN
# mnth        0.802477  0.804299     NaN NaN  1.000000 -0.025646 -0.105600
# hr          0.000060 -0.022421     NaN NaN -0.025646  1.000000 -0.005753
# holiday    -0.063013 -0.068456     NaN NaN -0.105600 -0.005753  1.000000
# weekday     0.008157  0.010248     NaN NaN  0.034710  0.007531 -0.148682
# weathersit  0.030439  0.033310     NaN NaN  0.014061 -0.055802  0.165443
# temp        0.023406  0.022342     NaN NaN  0.159660  0.203512 -0.059728
# atemp       0.077546  0.078681     NaN NaN  0.192216  0.148524 -0.072091
# hum         0.062116  0.073485     NaN NaN  0.066587 -0.194853 -0.037542
# ...

# %%
#To convert date column into float value using numeric method

# %%
concatenated_data['dteday'] = pd.to_numeric(concatenated_data['dteday'],errors='coerce')

# %%
#To check the skewness of the data
concatenated_data.skew(axis =0, skipna=True)
# Out:
# instant       0.000000
# dteday        0.007008
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# holiday       6.229578
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# atemp         0.435927
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64

# %%
concatenated_data.to_excel("project_2.xlsx")
